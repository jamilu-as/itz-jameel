# %% [markdown]
# <a href="https://colab.research.google.com/github/jamilu-as/itz-jameel/blob/master/2_Files_Vector_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Multi Document mapping

# %% [markdown]
# ####Libraries and Imports

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import torch

# %%
# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ### Load the data

# %%
file1 = pd.read_excel('SCF.xlsx')
file2 = pd.read_excel('aeIAS.xlsx')

# %% [markdown]
# ### Display the first few rows to verify successful loading

# %%
print("File1 Data Sample:")
display(file1.head())

print("\nFile2 Data Sample:")
display(file2.head())
# Out:
# File1 Data Sample:
#                                    SCF Domain  \
# 0  Cybersecurity & Data Protection Governance
# 1  Cybersecurity & Data Protection Governance
# 2  Cybersecurity & Data Protection Governance
# 3  Cybersecurity & Data Protection Governance
# 4  Cybersecurity & Data Protection Governance
#
#                                                Title     SCF #  \
# 0  Cybersecurity & Data Protection Governance Pro...    GOV-01
# 1             Steering Committee & Program Oversight  GOV-01.1
# 2                 Status Reporting To Governing Body  GOV-01.2
# 3  Publishing Cybersecurity & Data Protection Doc...    GOV-02
# 4                               Exception Management  GOV-02.1
#
#                                          Description  \
# 0  facilitate the implementation of cybersecurity...
# 1  coordinate cybersecurity, data protection and ...
# 2  provide governance oversight reporting and rec...
# 3  establish, maintain and disseminate cybersecur...
# 4  prohibit exceptions to standards, except when ...
#
#                        Evidence Request List (ERL) #  \
# 0                                 E-GOV-01\nE-GOV-02
# 1                                           E-GOV-03
# 2  E-CPL-05\nE-CPL-09\nE-GOV-03\nE-GOV-04\nE-GOV-...
# 3                       E-GOV-08\nE-GOV-09\nE-GOV-11
# 4                                                NaN
#
#   Possible Solutions & Considerations\nMicro-Small Business (<10 staff)\nBLS Firm Size Classes 1-2  \
# 0  ∙ ComplianceForge - Cybersecurity & Data Prote...
# 1    ∙ Third-party advisors (subject matter experts)
# 2                  ∙ Quarterly Business Review (QBR)
# 3  ∙ ComplianceForge - Cybersecurity & Data Prote...
# 4  ∙ Manual exception management process\n∙ SCFCo...
#
#   Possible Solutions & Considerations\nSmall Business (10-49 staff)\nBLS Firm Size Classes 3-4  \
# 0  ∙ ComplianceForge - Cybersecurity & Data Prote...
# 1    ∙ Third-party advisors (subject matter experts)
# 2                  ∙ Quarterly Business Review (QBR)
# 3  ∙ ComplianceForge - Cybersecurity & Data Prote...
# 4  ∙ Manual exception management process\n∙ Gover...
#
#   Possible Solutions & Considerations\nMedium Business (50-249 staff)\nBLS Firm Size Classes 5-6  \
# 0  ∙ Steering committee\n∙ ComplianceForge - Digi...
# 1              ∙ Steering committee / advisory board
# 2                  ∙ Quarterly Business Review (QBR)
# 3  ∙ ComplianceForge - Digital Security Program (...
# 4  ∙ Manual exception management process\n∙ Gover...
#
#   Possible Solutions & Considerations\nLarge Business (250-999 staff)\nBLS Firm Size Classes 7-8  \
# 0  ∙ Steering committee\n∙ ComplianceForge - Digi...
# 1              ∙ Steering committee / advisory board
# 2                  ∙ Quarterly Business Review (QBR)
# 3  ∙ ComplianceForge - Digital Security Program (...
# 4  ∙ Governance, Risk & Compliance (GRC) solution...
#
#   Possible Solutions & Considerations\nEnterprise (> 1,000 staff)\nBLS Firm Size Class 9  \
# 0  ∙ Steering committee\n∙ ComplianceForge - Digi...
# 1              ∙ Steering committee / advisory board
# 2                  ∙ Quarterly Business Review (QBR)
# 3  ∙ ComplianceForge - Digital Security Program (...
# 4  ∙ Governance, Risk & Compliance (GRC) solution...
#
#    ... Saudi Arabia\nSACS-002 Saudi Arabia\nECC-12018  \
# 0  ...                 TPC-25            1-2-1\n1-3-2
# 1  ...                    NaN                     NaN
# 2  ...                    NaN                     NaN
# 3  ...                 TPC-25            1-3-1\n1-3-3
# 4  ...                    NaN                     NaN
#
#   Saudi Arabia\nOTCC-1 2022 UAE\nDIFC Data Protection Law UAE \nIAS  \
# 0                       1-1                Sec 15\nSec 16    M1.4.1
# 1                       NaN                           NaN       NaN
# 2                       NaN                           NaN       NaN
# 3                1-1\n1-1-1                           NaN    T9.1.1
# 4                       NaN                           NaN       NaN
#
#                             UAE \nNESA Control Name UAE \nADSIC\nv2.0  \
# 0                                         RESOURCES            SG.1.9
# 1                                               NaN               NaN
# 2                                               NaN               NaN
# 3  INFORMATION SYSTEMS CONTINUITY MANAGEMENT POLICY              IC.1
# 4                                               NaN               NaN
#
#   UAE\nCBUAE Regulations MITRE\nATT&CK OWASP\nTop 10
# 0                    NaN           NaN           NaN
# 1                    NaN           NaN           NaN
# 2                    NaN           NaN           NaN
# 3                    NaN           NaN           NaN
# 4                    NaN           NaN           NaN
#
# [5 rows x 34 columns]
# File2 Data Sample:
#          ID                                     Title  \
# 0        M1                     strategy and planning
# 1      M1.1             entity context and leadership
# 2    M1.1.1  understanding the entity and its context
# 3  M1.1.1.1  understanding the entity and its context
# 4  M1.1.1.2  understanding the entity and its context
#
#                                          Description
# 0  To provide an adequate organizational environm...
# 1  To establish leadership and a management frame...
# 2   determine external and internal factors that ...
# 3   determine interested parties that are relevan...
# 4   determine the requirements of these intereste...

# %% [markdown]
# ### Initialize the model and tokenizer

# %%
model_name = "sentence-transformers/all-mpnet-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %% [markdown]
# # Function to generate embeddings for Title + Description

# %%
def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# %% [markdown]
# ### Concatenate Title and Description for embedding generation

# %%
file1['text_combined'] = file1['Title'] + " " + file1['Description']
file2['text_combined'] = file2['Title'] + " " + file2['Description']

# %%
print("File1 Data Sample with Combined Text:")
display(file1['text_combined'].head())

print("\nFile2 Data Sample with Combined Text:")
display(file2['text_combined'].head())
# Out:
# File1 Data Sample with Combined Text:
# 0    Cybersecurity & Data Protection Governance Pro...
# 1    Steering Committee & Program Oversight coordin...
# 2    Status Reporting To Governing Body provide gov...
# 3    Publishing Cybersecurity & Data Protection Doc...
# 4    Exception Management prohibit exceptions to st...
# Name: text_combined, dtype: object
# File2 Data Sample with Combined Text:
# 0    strategy and planning To provide an adequate o...
# 1    entity context and leadership To establish lea...
# 2    understanding the entity and its context  dete...
# 3    understanding the entity and its context  dete...
# 4    understanding the entity and its context  dete...
# Name: text_combined, dtype: object

# %% [markdown]
# ### Generate embeddings for the combined text for each control

# %%
file1['embedding'] = file1['text_combined'].apply(lambda x: get_embedding(x))
file2['embedding'] = file2['text_combined'].apply(lambda x: get_embedding(x))

# %% [markdown]
# ### Check that embeddings have the correct shape

# %%
for idx, emb in enumerate(file1['embedding']):
    print(f"File1 embedding at row {idx}: Shape {emb.shape}")
for idx, emb in enumerate(file2['embedding']):
    print(f"File2 embedding at row {idx}: Shape {emb.shape}")
# Out:
# File1 embedding at row 0: Shape (768,)
# File1 embedding at row 1: Shape (768,)
# File1 embedding at row 2: Shape (768,)
# File1 embedding at row 3: Shape (768,)
# File1 embedding at row 4: Shape (768,)
# File1 embedding at row 5: Shape (768,)
# File1 embedding at row 6: Shape (768,)
# File1 embedding at row 7: Shape (768,)
# File1 embedding at row 8: Shape (768,)
# File1 embedding at row 9: Shape (768,)
# File1 embedding at row 10: Shape (768,)
# File1 embedding at row 11: Shape (768,)
# File1 embedding at row 12: Shape (768,)
# File1 embedding at row 13: Shape (768,)
# File1 embedding at row 14: Shape (768,)
# File1 embedding at row 15: Shape (768,)
# File1 embedding at row 16: Shape (768,)
# File1 embedding at row 17: Shape (768,)
# File1 embedding at row 18: Shape (768,)
# File1 embedding at row 19: Shape (768,)
# File1 embedding at row 20: Shape (768,)
# File1 embedding at row 21: Shape (768,)
# File1 embedding at row 22: Shape (768,)
# File1 embedding at row 23: Shape (768,)
# File1 embedding at row 24: Shape (768,)
# File1 embedding at row 25: Shape (768,)
# File1 embedding at row 26: Shape (768,)
# File1 embedding at row 27: Shape (768,)
# File1 embedding at row 28: Shape (768,)
# File1 embedding at row 29: Shape (768,)
# File1 embedding at row 30: Shape (768,)
# File1 embedding at row 31: Shape (768,)
# File1 embedding at row 32: Shape (768,)
# File1 embedding at row 33: Shape (768,)
# File1 embedding at row 34: Shape (768,)
# File1 embedding at row 35: Shape (768,)
# File1 embedding at row 36: Shape (768,)
# File1 embedding at row 37: Shape (768,)
# File1 embedding at row 38: Shape (768,)
# File1 embedding at row 39: Shape (768,)
# File1 embedding at row 40: Shape (768,)
# File1 embedding at row 41: Shape (768,)
# File1 embedding at row 42: Shape (768,)
# File1 embedding at row 43: Shape (768,)
# File1 embedding at row 44: Shape (768,)
# File1 embedding at row 45: Shape (768,)
# File1 embedding at row 46: Shape (768,)
# File1 embedding at row 47: Shape (768,)
# File1 embedding at row 48: Shape (768,)
# File1 embedding at row 49: Shape (768,)
# File1 embedding at row 50: Shape (768,)
# File1 embedding at row 51: Shape (768,)
# File1 embedding at row 52: Shape (768,)
# File1 embedding at row 53: Shape (768,)
# File1 embedding at row 54: Shape (768,)
# File1 embedding at row 55: Shape (768,)
# File1 embedding at row 56: Shape (768,)
# File1 embedding at row 57: Shape (768,)
# File1 embedding at row 58: Shape (768,)
# File1 embedding at row 59: Shape (768,)
# File1 embedding at row 60: Shape (768,)
# File1 embedding at row 61: Shape (768,)
# File1 embedding at row 62: Shape (768,)
# File1 embedding at row 63: Shape (768,)
# File1 embedding at row 64: Shape (768,)
# File1 embedding at row 65: Shape (768,)
# File1 embedding at row 66: Shape (768,)
# File1 embedding at row 67: Shape (768,)
# File1 embedding at row 68: Shape (768,)
# File1 embedding at row 69: Shape (768,)
# File1 embedding at row 70: Shape (768,)
# File1 embedding at row 71: Shape (768,)
# File1 embedding at row 72: Shape (768,)
# File1 embedding at row 73: Shape (768,)
# File1 embedding at row 74: Shape (768,)
# File1 embedding at row 75: Shape (768,)
# File1 embedding at row 76: Shape (768,)
# File1 embedding at row 77: Shape (768,)
# File1 embedding at row 78: Shape (768,)
# File1 embedding at row 79: Shape (768,)
# File1 embedding at row 80: Shape (768,)
# File1 embedding at row 81: Shape (768,)
# File1 embedding at row 82: Shape (768,)
# File1 embedding at row 83: Shape (768,)
# File1 embedding at row 84: Shape (768,)
# File1 embedding at row 85: Shape (768,)
# File1 embedding at row 86: Shape (768,)
# File1 embedding at row 87: Shape (768,)
# File1 embedding at row 88: Shape (768,)
# File1 embedding at row 89: Shape (768,)
# File1 embedding at row 90: Shape (768,)
# File1 embedding at row 91: Shape (768,)
# File1 embedding at row 92: Shape (768,)
# File1 embedding at row 93: Shape (768,)
# File1 embedding at row 94: Shape (768,)
# File1 embedding at row 95: Shape (768,)
# File1 embedding at row 96: Shape (768,)
# File1 embedding at row 97: Shape (768,)
# File1 embedding at row 98: Shape (768,)
# File1 embedding at row 99: Shape (768,)
# File1 embedding at row 100: Shape (768,)
# File1 embedding at row 101: Shape (768,)
# File1 embedding at row 102: Shape (768,)
# File1 embedding at row 103: Shape (768,)
# File1 embedding at row 104: Shape (768,)
# File1 embedding at row 105: Shape (768,)
# File1 embedding at row 106: Shape (768,)
# File1 embedding at row 107: Shape (768,)
# File1 embedding at row 108: Shape (768,)
# File1 embedding at row 109: Shape (768,)
# File1 embedding at row 110: Shape (768,)
# File1 embedding at row 111: Shape (768,)
# File1 embedding at row 112: Shape (768,)
# File1 embedding at row 113: Shape (768,)
# File1 embedding at row 114: Shape (768,)
# File1 embedding at row 115: Shape (768,)
# File1 embedding at row 116: Shape (768,)
# File1 embedding at row 117: Shape (768,)
# File1 embedding at row 118: Shape (768,)
# File1 embedding at row 119: Shape (768,)
# File1 embedding at row 120: Shape (768,)
# File1 embedding at row 121: Shape (768,)
# File1 embedding at row 122: Shape (768,)
# File1 embedding at row 123: Shape (768,)
# File1 embedding at row 124: Shape (768,)
# File1 embedding at row 125: Shape (768,)
# File1 embedding at row 126: Shape (768,)
# File1 embedding at row 127: Shape (768,)
# File1 embedding at row 128: Shape (768,)
# File1 embedding at row 129: Shape (768,)
# File1 embedding at row 130: Shape (768,)
# File1 embedding at row 131: Shape (768,)
# File1 embedding at row 132: Shape (768,)
# File1 embedding at row 133: Shape (768,)
# File1 embedding at row 134: Shape (768,)
# File1 embedding at row 135: Shape (768,)
# File1 embedding at row 136: Shape (768,)
# File1 embedding at row 137: Shape (768,)
# File1 embedding at row 138: Shape (768,)
# File1 embedding at row 139: Shape (768,)
# File1 embedding at row 140: Shape (768,)
# File1 embedding at row 141: Shape (768,)
# File1 embedding at row 142: Shape (768,)
# File1 embedding at row 143: Shape (768,)
# File1 embedding at row 144: Shape (768,)
# File1 embedding at row 145: Shape (768,)
# File1 embedding at row 146: Shape (768,)
# File1 embedding at row 147: Shape (768,)
# File1 embedding at row 148: Shape (768,)
# File1 embedding at row 149: Shape (768,)
# File1 embedding at row 150: Shape (768,)
# File1 embedding at row 151: Shape (768,)
# File1 embedding at row 152: Shape (768,)
# File1 embedding at row 153: Shape (768,)
# File1 embedding at row 154: Shape (768,)
# File1 embedding at row 155: Shape (768,)
# File1 embedding at row 156: Shape (768,)
# File1 embedding at row 157: Shape (768,)
# File1 embedding at row 158: Shape (768,)
# File1 embedding at row 159: Shape (768,)
# File1 embedding at row 160: Shape (768,)
# File1 embedding at row 161: Shape (768,)
# File1 embedding at row 162: Shape (768,)
# File1 embedding at row 163: Shape (768,)
# File1 embedding at row 164: Shape (768,)
# File1 embedding at row 165: Shape (768,)
# File1 embedding at row 166: Shape (768,)
# File1 embedding at row 167: Shape (768,)
# File1 embedding at row 168: Shape (768,)
# File1 embedding at row 169: Shape (768,)
# File1 embedding at row 170: Shape (768,)
# File1 embedding at row 171: Shape (768,)
# File1 embedding at row 172: Shape (768,)
# File1 embedding at row 173: Shape (768,)
# File1 embedding at row 174: Shape (768,)
# File1 embedding at row 175: Shape (768,)
# File1 embedding at row 176: Shape (768,)
# File1 embedding at row 177: Shape (768,)
# File1 embedding at row 178: Shape (768,)
# File1 embedding at row 179: Shape (768,)
# File1 embedding at row 180: Shape (768,)
# File1 embedding at row 181: Shape (768,)
# File1 embedding at row 182: Shape (768,)
# File1 embedding at row 183: Shape (768,)
# File1 embedding at row 184: Shape (768,)
# File1 embedding at row 185: Shape (768,)
# File1 embedding at row 186: Shape (768,)
# File1 embedding at row 187: Shape (768,)
# File1 embedding at row 188: Shape (768,)
# File1 embedding at row 189: Shape (768,)
# File1 embedding at row 190: Shape (768,)
# File1 embedding at row 191: Shape (768,)
# File1 embedding at row 192: Shape (768,)
# File1 embedding at row 193: Shape (768,)
# File1 embedding at row 194: Shape (768,)
# File1 embedding at row 195: Shape (768,)
# File1 embedding at row 196: Shape (768,)
# File1 embedding at row 197: Shape (768,)
# File1 embedding at row 198: Shape (768,)
# File1 embedding at row 199: Shape (768,)
# File1 embedding at row 200: Shape (768,)
# File1 embedding at row 201: Shape (768,)
# File1 embedding at row 202: Shape (768,)
# File1 embedding at row 203: Shape (768,)
# File1 embedding at row 204: Shape (768,)
# File1 embedding at row 205: Shape (768,)
# File1 embedding at row 206: Shape (768,)
# File1 embedding at row 207: Shape (768,)
# File1 embedding at row 208: Shape (768,)
# File1 embedding at row 209: Shape (768,)
# File1 embedding at row 210: Shape (768,)
# File1 embedding at row 211: Shape (768,)
# File1 embedding at row 212: Shape (768,)
# File1 embedding at row 213: Shape (768,)
# File1 embedding at row 214: Shape (768,)
# File1 embedding at row 215: Shape (768,)
# File1 embedding at row 216: Shape (768,)
# File1 embedding at row 217: Shape (768,)
# File1 embedding at row 218: Shape (768,)
# File1 embedding at row 219: Shape (768,)
# File1 embedding at row 220: Shape (768,)
# File1 embedding at row 221: Shape (768,)
# File1 embedding at row 222: Shape (768,)
# File1 embedding at row 223: Shape (768,)
# File1 embedding at row 224: Shape (768,)
# File1 embedding at row 225: Shape (768,)
# File1 embedding at row 226: Shape (768,)
# File1 embedding at row 227: Shape (768,)
# File1 embedding at row 228: Shape (768,)
# File1 embedding at row 229: Shape (768,)
# File1 embedding at row 230: Shape (768,)
# File1 embedding at row 231: Shape (768,)
# File1 embedding at row 232: Shape (768,)
# File1 embedding at row 233: Shape (768,)
# File1 embedding at row 234: Shape (768,)
# File1 embedding at row 235: Shape (768,)
# File1 embedding at row 236: Shape (768,)
# File1 embedding at row 237: Shape (768,)
# File1 embedding at row 238: Shape (768,)
# File1 embedding at row 239: Shape (768,)
# File1 embedding at row 240: Shape (768,)
# File1 embedding at row 241: Shape (768,)
# File1 embedding at row 242: Shape (768,)
# File1 embedding at row 243: Shape (768,)
# File1 embedding at row 244: Shape (768,)
# File1 embedding at row 245: Shape (768,)
# File1 embedding at row 246: Shape (768,)
# File1 embedding at row 247: Shape (768,)
# File1 embedding at row 248: Shape (768,)
# File1 embedding at row 249: Shape (768,)
# File1 embedding at row 250: Shape (768,)
# File1 embedding at row 251: Shape (768,)
# File1 embedding at row 252: Shape (768,)
# File1 embedding at row 253: Shape (768,)
# File1 embedding at row 254: Shape (768,)
# File1 embedding at row 255: Shape (768,)
# File1 embedding at row 256: Shape (768,)
# File1 embedding at row 257: Shape (768,)
# File1 embedding at row 258: Shape (768,)
# File1 embedding at row 259: Shape (768,)
# File1 embedding at row 260: Shape (768,)
# File1 embedding at row 261: Shape (768,)
# File1 embedding at row 262: Shape (768,)
# File1 embedding at row 263: Shape (768,)
# File1 embedding at row 264: Shape (768,)
# File1 embedding at row 265: Shape (768,)
# File1 embedding at row 266: Shape (768,)
# File1 embedding at row 267: Shape (768,)
# File1 embedding at row 268: Shape (768,)
# File1 embedding at row 269: Shape (768,)
# File1 embedding at row 270: Shape (768,)
# File1 embedding at row 271: Shape (768,)
# File1 embedding at row 272: Shape (768,)
# File1 embedding at row 273: Shape (768,)
# File1 embedding at row 274: Shape (768,)
# File1 embedding at row 275: Shape (768,)
# File1 embedding at row 276: Shape (768,)
# File1 embedding at row 277: Shape (768,)
# File1 embedding at row 278: Shape (768,)
# File1 embedding at row 279: Shape (768,)
# File1 embedding at row 280: Shape (768,)
# File1 embedding at row 281: Shape (768,)
# File1 embedding at row 282: Shape (768,)
# File1 embedding at row 283: Shape (768,)
# File1 embedding at row 284: Shape (768,)
# File1 embedding at row 285: Shape (768,)
# File1 embedding at row 286: Shape (768,)
# File1 embedding at row 287: Shape (768,)
# File1 embedding at row 288: Shape (768,)
# File1 embedding at row 289: Shape (768,)
# File1 embedding at row 290: Shape (768,)
# File1 embedding at row 291: Shape (768,)
# File1 embedding at row 292: Shape (768,)
# File1 embedding at row 293: Shape (768,)
# File1 embedding at row 294: Shape (768,)
# File1 embedding at row 295: Shape (768,)
# File1 embedding at row 296: Shape (768,)
# File1 embedding at row 297: Shape (768,)
# File1 embedding at row 298: Shape (768,)
# File1 embedding at row 299: Shape (768,)
# File1 embedding at row 300: Shape (768,)
# File1 embedding at row 301: Shape (768,)
# File1 embedding at row 302: Shape (768,)
# File1 embedding at row 303: Shape (768,)
# File1 embedding at row 304: Shape (768,)
# File1 embedding at row 305: Shape (768,)
# File1 embedding at row 306: Shape (768,)
# File1 embedding at row 307: Shape (768,)
# File1 embedding at row 308: Shape (768,)
# File1 embedding at row 309: Shape (768,)
# File1 embedding at row 310: Shape (768,)
# File1 embedding at row 311: Shape (768,)
# File1 embedding at row 312: Shape (768,)
# File1 embedding at row 313: Shape (768,)
# File1 embedding at row 314: Shape (768,)
# File1 embedding at row 315: Shape (768,)
# File1 embedding at row 316: Shape (768,)
# File1 embedding at row 317: Shape (768,)
# File1 embedding at row 318: Shape (768,)
# File1 embedding at row 319: Shape (768,)
# File1 embedding at row 320: Shape (768,)
# File1 embedding at row 321: Shape (768,)
# File1 embedding at row 322: Shape (768,)
# File1 embedding at row 323: Shape (768,)
# File1 embedding at row 324: Shape (768,)
# File1 embedding at row 325: Shape (768,)
# File1 embedding at row 326: Shape (768,)
# File1 embedding at row 327: Shape (768,)
# File1 embedding at row 328: Shape (768,)
# File1 embedding at row 329: Shape (768,)
# File1 embedding at row 330: Shape (768,)
# File1 embedding at row 331: Shape (768,)
# File1 embedding at row 332: Shape (768,)
# File1 embedding at row 333: Shape (768,)
# File1 embedding at row 334: Shape (768,)
# File1 embedding at row 335: Shape (768,)
# File1 embedding at row 336: Shape (768,)
# File1 embedding at row 337: Shape (768,)
# File1 embedding at row 338: Shape (768,)
# File1 embedding at row 339: Shape (768,)
# File1 embedding at row 340: Shape (768,)
# File1 embedding at row 341: Shape (768,)
# File1 embedding at row 342: Shape (768,)
# File1 embedding at row 343: Shape (768,)
# File1 embedding at row 344: Shape (768,)
# File1 embedding at row 345: Shape (768,)
# File1 embedding at row 346: Shape (768,)
# File1 embedding at row 347: Shape (768,)
# File1 embedding at row 348: Shape (768,)
# File1 embedding at row 349: Shape (768,)
# File1 embedding at row 350: Shape (768,)
# File1 embedding at row 351: Shape (768,)
# File1 embedding at row 352: Shape (768,)
# File1 embedding at row 353: Shape (768,)
# File1 embedding at row 354: Shape (768,)
# File1 embedding at row 355: Shape (768,)
# File1 embedding at row 356: Shape (768,)
# File1 embedding at row 357: Shape (768,)
# File1 embedding at row 358: Shape (768,)
# File1 embedding at row 359: Shape (768,)
# File1 embedding at row 360: Shape (768,)
# File1 embedding at row 361: Shape (768,)
# File1 embedding at row 362: Shape (768,)
# File1 embedding at row 363: Shape (768,)
# File1 embedding at row 364: Shape (768,)
# File1 embedding at row 365: Shape (768,)
# File1 embedding at row 366: Shape (768,)
# File1 embedding at row 367: Shape (768,)
# File1 embedding at row 368: Shape (768,)
# File1 embedding at row 369: Shape (768,)
# File1 embedding at row 370: Shape (768,)
# File1 embedding at row 371: Shape (768,)
# File1 embedding at row 372: Shape (768,)
# File1 embedding at row 373: Shape (768,)
# File1 embedding at row 374: Shape (768,)
# File1 embedding at row 375: Shape (768,)
# File1 embedding at row 376: Shape (768,)
# File1 embedding at row 377: Shape (768,)
# File1 embedding at row 378: Shape (768,)
# File1 embedding at row 379: Shape (768,)
# File1 embedding at row 380: Shape (768,)
# File1 embedding at row 381: Shape (768,)
# File1 embedding at row 382: Shape (768,)
# File1 embedding at row 383: Shape (768,)
# File1 embedding at row 384: Shape (768,)
# File1 embedding at row 385: Shape (768,)
# File1 embedding at row 386: Shape (768,)
# File1 embedding at row 387: Shape (768,)
# File1 embedding at row 388: Shape (768,)
# File1 embedding at row 389: Shape (768,)
# File1 embedding at row 390: Shape (768,)
# File1 embedding at row 391: Shape (768,)
# File1 embedding at row 392: Shape (768,)
# File1 embedding at row 393: Shape (768,)
# File1 embedding at row 394: Shape (768,)
# File1 embedding at row 395: Shape (768,)
# File1 embedding at row 396: Shape (768,)
# File1 embedding at row 397: Shape (768,)
# File1 embedding at row 398: Shape (768,)
# File1 embedding at row 399: Shape (768,)
# File1 embedding at row 400: Shape (768,)
# File1 embedding at row 401: Shape (768,)
# File1 embedding at row 402: Shape (768,)
# File1 embedding at row 403: Shape (768,)
# File1 embedding at row 404: Shape (768,)
# File1 embedding at row 405: Shape (768,)
# File1 embedding at row 406: Shape (768,)
# File1 embedding at row 407: Shape (768,)
# File1 embedding at row 408: Shape (768,)
# File1 embedding at row 409: Shape (768,)
# File1 embedding at row 410: Shape (768,)
# File1 embedding at row 411: Shape (768,)
# File1 embedding at row 412: Shape (768,)
# File1 embedding at row 413: Shape (768,)
# File1 embedding at row 414: Shape (768,)
# File1 embedding at row 415: Shape (768,)
# File1 embedding at row 416: Shape (768,)
# File1 embedding at row 417: Shape (768,)
# File1 embedding at row 418: Shape (768,)
# File1 embedding at row 419: Shape (768,)
# File1 embedding at row 420: Shape (768,)
# File1 embedding at row 421: Shape (768,)
# File1 embedding at row 422: Shape (768,)
# File1 embedding at row 423: Shape (768,)
# File1 embedding at row 424: Shape (768,)
# File1 embedding at row 425: Shape (768,)
# File1 embedding at row 426: Shape (768,)
# File1 embedding at row 427: Shape (768,)
# File1 embedding at row 428: Shape (768,)
# File1 embedding at row 429: Shape (768,)
# File1 embedding at row 430: Shape (768,)
# File1 embedding at row 431: Shape (768,)
# File1 embedding at row 432: Shape (768,)
# File1 embedding at row 433: Shape (768,)
# File1 embedding at row 434: Shape (768,)
# File1 embedding at row 435: Shape (768,)
# File1 embedding at row 436: Shape (768,)
# File1 embedding at row 437: Shape (768,)
# File1 embedding at row 438: Shape (768,)
# File1 embedding at row 439: Shape (768,)
# File1 embedding at row 440: Shape (768,)
# File1 embedding at row 441: Shape (768,)
# File1 embedding at row 442: Shape (768,)
# File1 embedding at row 443: Shape (768,)
# File1 embedding at row 444: Shape (768,)
# File1 embedding at row 445: Shape (768,)
# File1 embedding at row 446: Shape (768,)
# File1 embedding at row 447: Shape (768,)
# File1 embedding at row 448: Shape (768,)
# File1 embedding at row 449: Shape (768,)
# File1 embedding at row 450: Shape (768,)
# File1 embedding at row 451: Shape (768,)
# File1 embedding at row 452: Shape (768,)
# File1 embedding at row 453: Shape (768,)
# File1 embedding at row 454: Shape (768,)
# File1 embedding at row 455: Shape (768,)
# File1 embedding at row 456: Shape (768,)
# File1 embedding at row 457: Shape (768,)
# File1 embedding at row 458: Shape (768,)
# File1 embedding at row 459: Shape (768,)
# File1 embedding at row 460: Shape (768,)
# File1 embedding at row 461: Shape (768,)
# File1 embedding at row 462: Shape (768,)
# File1 embedding at row 463: Shape (768,)
# File1 embedding at row 464: Shape (768,)
# File1 embedding at row 465: Shape (768,)
# File1 embedding at row 466: Shape (768,)
# File1 embedding at row 467: Shape (768,)
# File1 embedding at row 468: Shape (768,)
# File1 embedding at row 469: Shape (768,)
# File1 embedding at row 470: Shape (768,)
# File1 embedding at row 471: Shape (768,)
# File1 embedding at row 472: Shape (768,)
# File1 embedding at row 473: Shape (768,)
# File1 embedding at row 474: Shape (768,)
# File1 embedding at row 475: Shape (768,)
# File1 embedding at row 476: Shape (768,)
# File1 embedding at row 477: Shape (768,)
# File1 embedding at row 478: Shape (768,)
# File1 embedding at row 479: Shape (768,)
# File1 embedding at row 480: Shape (768,)
# File1 embedding at row 481: Shape (768,)
# File1 embedding at row 482: Shape (768,)
# File1 embedding at row 483: Shape (768,)
# File1 embedding at row 484: Shape (768,)
# File1 embedding at row 485: Shape (768,)
# File1 embedding at row 486: Shape (768,)
# File1 embedding at row 487: Shape (768,)
# File1 embedding at row 488: Shape (768,)
# File1 embedding at row 489: Shape (768,)
# File1 embedding at row 490: Shape (768,)
# File1 embedding at row 491: Shape (768,)
# File1 embedding at row 492: Shape (768,)
# File1 embedding at row 493: Shape (768,)
# File1 embedding at row 494: Shape (768,)
# File1 embedding at row 495: Shape (768,)
# File1 embedding at row 496: Shape (768,)
# File1 embedding at row 497: Shape (768,)
# File1 embedding at row 498: Shape (768,)
# File1 embedding at row 499: Shape (768,)
# File1 embedding at row 500: Shape (768,)
# File1 embedding at row 501: Shape (768,)
# File1 embedding at row 502: Shape (768,)
# File1 embedding at row 503: Shape (768,)
# File1 embedding at row 504: Shape (768,)
# File1 embedding at row 505: Shape (768,)
# File1 embedding at row 506: Shape (768,)
# File1 embedding at row 507: Shape (768,)
# File1 embedding at row 508: Shape (768,)
# File1 embedding at row 509: Shape (768,)
# File1 embedding at row 510: Shape (768,)
# File1 embedding at row 511: Shape (768,)
# File1 embedding at row 512: Shape (768,)
# File1 embedding at row 513: Shape (768,)
# File1 embedding at row 514: Shape (768,)
# File1 embedding at row 515: Shape (768,)
# File1 embedding at row 516: Shape (768,)
# File1 embedding at row 517: Shape (768,)
# File1 embedding at row 518: Shape (768,)
# File1 embedding at row 519: Shape (768,)
# File1 embedding at row 520: Shape (768,)
# File1 embedding at row 521: Shape (768,)
# File1 embedding at row 522: Shape (768,)
# File1 embedding at row 523: Shape (768,)
# File1 embedding at row 524: Shape (768,)
# File1 embedding at row 525: Shape (768,)
# File1 embedding at row 526: Shape (768,)
# File1 embedding at row 527: Shape (768,)
# File1 embedding at row 528: Shape (768,)
# File1 embedding at row 529: Shape (768,)
# File1 embedding at row 530: Shape (768,)
# File1 embedding at row 531: Shape (768,)
# File1 embedding at row 532: Shape (768,)
# File1 embedding at row 533: Shape (768,)
# File1 embedding at row 534: Shape (768,)
# File1 embedding at row 535: Shape (768,)
# File1 embedding at row 536: Shape (768,)
# File1 embedding at row 537: Shape (768,)
# File1 embedding at row 538: Shape (768,)
# File1 embedding at row 539: Shape (768,)
# File1 embedding at row 540: Shape (768,)
# File1 embedding at row 541: Shape (768,)
# File1 embedding at row 542: Shape (768,)
# File1 embedding at row 543: Shape (768,)
# File1 embedding at row 544: Shape (768,)
# File1 embedding at row 545: Shape (768,)
# File1 embedding at row 546: Shape (768,)
# File1 embedding at row 547: Shape (768,)
# File1 embedding at row 548: Shape (768,)
# File1 embedding at row 549: Shape (768,)
# File1 embedding at row 550: Shape (768,)
# File1 embedding at row 551: Shape (768,)
# File1 embedding at row 552: Shape (768,)
# File1 embedding at row 553: Shape (768,)
# File1 embedding at row 554: Shape (768,)
# File1 embedding at row 555: Shape (768,)
# File1 embedding at row 556: Shape (768,)
# File1 embedding at row 557: Shape (768,)
# File1 embedding at row 558: Shape (768,)
# File1 embedding at row 559: Shape (768,)
# File1 embedding at row 560: Shape (768,)
# File1 embedding at row 561: Shape (768,)
# File1 embedding at row 562: Shape (768,)
# File1 embedding at row 563: Shape (768,)
# File1 embedding at row 564: Shape (768,)
# File1 embedding at row 565: Shape (768,)
# File1 embedding at row 566: Shape (768,)
# File1 embedding at row 567: Shape (768,)
# File1 embedding at row 568: Shape (768,)
# File1 embedding at row 569: Shape (768,)
# File1 embedding at row 570: Shape (768,)
# File1 embedding at row 571: Shape (768,)
# File1 embedding at row 572: Shape (768,)
# File1 embedding at row 573: Shape (768,)
# File1 embedding at row 574: Shape (768,)
# File1 embedding at row 575: Shape (768,)
# File1 embedding at row 576: Shape (768,)
# File1 embedding at row 577: Shape (768,)
# File1 embedding at row 578: Shape (768,)
# File1 embedding at row 579: Shape (768,)
# File1 embedding at row 580: Shape (768,)
# File1 embedding at row 581: Shape (768,)
# File1 embedding at row 582: Shape (768,)
# File1 embedding at row 583: Shape (768,)
# File1 embedding at row 584: Shape (768,)
# File1 embedding at row 585: Shape (768,)
# File1 embedding at row 586: Shape (768,)
# File1 embedding at row 587: Shape (768,)
# File1 embedding at row 588: Shape (768,)
# File1 embedding at row 589: Shape (768,)
# File1 embedding at row 590: Shape (768,)
# File1 embedding at row 591: Shape (768,)
# File1 embedding at row 592: Shape (768,)
# File1 embedding at row 593: Shape (768,)
# File1 embedding at row 594: Shape (768,)
# File1 embedding at row 595: Shape (768,)
# File1 embedding at row 596: Shape (768,)
# File1 embedding at row 597: Shape (768,)
# File1 embedding at row 598: Shape (768,)
# File1 embedding at row 599: Shape (768,)
# File1 embedding at row 600: Shape (768,)
# File1 embedding at row 601: Shape (768,)
# File1 embedding at row 602: Shape (768,)
# File1 embedding at row 603: Shape (768,)
# File1 embedding at row 604: Shape (768,)
# File1 embedding at row 605: Shape (768,)
# File1 embedding at row 606: Shape (768,)
# File1 embedding at row 607: Shape (768,)
# File1 embedding at row 608: Shape (768,)
# File1 embedding at row 609: Shape (768,)
# File1 embedding at row 610: Shape (768,)
# File1 embedding at row 611: Shape (768,)
# File1 embedding at row 612: Shape (768,)
# File1 embedding at row 613: Shape (768,)
# File1 embedding at row 614: Shape (768,)
# File1 embedding at row 615: Shape (768,)
# File1 embedding at row 616: Shape (768,)
# File1 embedding at row 617: Shape (768,)
# File1 embedding at row 618: Shape (768,)
# File1 embedding at row 619: Shape (768,)
# File1 embedding at row 620: Shape (768,)
# File1 embedding at row 621: Shape (768,)
# File1 embedding at row 622: Shape (768,)
# File1 embedding at row 623: Shape (768,)
# File1 embedding at row 624: Shape (768,)
# File1 embedding at row 625: Shape (768,)
# File1 embedding at row 626: Shape (768,)
# File1 embedding at row 627: Shape (768,)
# File1 embedding at row 628: Shape (768,)
# File1 embedding at row 629: Shape (768,)
# File1 embedding at row 630: Shape (768,)
# File1 embedding at row 631: Shape (768,)
# File1 embedding at row 632: Shape (768,)
# File1 embedding at row 633: Shape (768,)
# File1 embedding at row 634: Shape (768,)
# File1 embedding at row 635: Shape (768,)
# File1 embedding at row 636: Shape (768,)
# File1 embedding at row 637: Shape (768,)
# File1 embedding at row 638: Shape (768,)
# File1 embedding at row 639: Shape (768,)
# File1 embedding at row 640: Shape (768,)
# File1 embedding at row 641: Shape (768,)
# File1 embedding at row 642: Shape (768,)
# File1 embedding at row 643: Shape (768,)
# File1 embedding at row 644: Shape (768,)
# File1 embedding at row 645: Shape (768,)
# File1 embedding at row 646: Shape (768,)
# File1 embedding at row 647: Shape (768,)
# File1 embedding at row 648: Shape (768,)
# File1 embedding at row 649: Shape (768,)
# File1 embedding at row 650: Shape (768,)
# File1 embedding at row 651: Shape (768,)
# File1 embedding at row 652: Shape (768,)
# File1 embedding at row 653: Shape (768,)
# File1 embedding at row 654: Shape (768,)
# File1 embedding at row 655: Shape (768,)
# File1 embedding at row 656: Shape (768,)
# File1 embedding at row 657: Shape (768,)
# File1 embedding at row 658: Shape (768,)
# File1 embedding at row 659: Shape (768,)
# File1 embedding at row 660: Shape (768,)
# File1 embedding at row 661: Shape (768,)
# File1 embedding at row 662: Shape (768,)
# File1 embedding at row 663: Shape (768,)
# File1 embedding at row 664: Shape (768,)
# File1 embedding at row 665: Shape (768,)
# File1 embedding at row 666: Shape (768,)
# File1 embedding at row 667: Shape (768,)
# File1 embedding at row 668: Shape (768,)
# File1 embedding at row 669: Shape (768,)
# File1 embedding at row 670: Shape (768,)
# File1 embedding at row 671: Shape (768,)
# File1 embedding at row 672: Shape (768,)
# File1 embedding at row 673: Shape (768,)
# File1 embedding at row 674: Shape (768,)
# File1 embedding at row 675: Shape (768,)
# File1 embedding at row 676: Shape (768,)
# File1 embedding at row 677: Shape (768,)
# File1 embedding at row 678: Shape (768,)
# File1 embedding at row 679: Shape (768,)
# File1 embedding at row 680: Shape (768,)
# File1 embedding at row 681: Shape (768,)
# File1 embedding at row 682: Shape (768,)
# File1 embedding at row 683: Shape (768,)
# File1 embedding at row 684: Shape (768,)
# File1 embedding at row 685: Shape (768,)
# File1 embedding at row 686: Shape (768,)
# File1 embedding at row 687: Shape (768,)
# File1 embedding at row 688: Shape (768,)
# File1 embedding at row 689: Shape (768,)
# File1 embedding at row 690: Shape (768,)
# File1 embedding at row 691: Shape (768,)
# File1 embedding at row 692: Shape (768,)
# File1 embedding at row 693: Shape (768,)
# File1 embedding at row 694: Shape (768,)
# File1 embedding at row 695: Shape (768,)
# File1 embedding at row 696: Shape (768,)
# File1 embedding at row 697: Shape (768,)
# File1 embedding at row 698: Shape (768,)
# File1 embedding at row 699: Shape (768,)
# File1 embedding at row 700: Shape (768,)
# File1 embedding at row 701: Shape (768,)
# File1 embedding at row 702: Shape (768,)
# File1 embedding at row 703: Shape (768,)
# File1 embedding at row 704: Shape (768,)
# File1 embedding at row 705: Shape (768,)
# File1 embedding at row 706: Shape (768,)
# File1 embedding at row 707: Shape (768,)
# File1 embedding at row 708: Shape (768,)
# File1 embedding at row 709: Shape (768,)
# File1 embedding at row 710: Shape (768,)
# File1 embedding at row 711: Shape (768,)
# File1 embedding at row 712: Shape (768,)
# File1 embedding at row 713: Shape (768,)
# File1 embedding at row 714: Shape (768,)
# File1 embedding at row 715: Shape (768,)
# File1 embedding at row 716: Shape (768,)
# File1 embedding at row 717: Shape (768,)
# File1 embedding at row 718: Shape (768,)
# File1 embedding at row 719: Shape (768,)
# File1 embedding at row 720: Shape (768,)
# File1 embedding at row 721: Shape (768,)
# File1 embedding at row 722: Shape (768,)
# File1 embedding at row 723: Shape (768,)
# File1 embedding at row 724: Shape (768,)
# File1 embedding at row 725: Shape (768,)
# File1 embedding at row 726: Shape (768,)
# File1 embedding at row 727: Shape (768,)
# File1 embedding at row 728: Shape (768,)
# File1 embedding at row 729: Shape (768,)
# File1 embedding at row 730: Shape (768,)
# File1 embedding at row 731: Shape (768,)
# File1 embedding at row 732: Shape (768,)
# File1 embedding at row 733: Shape (768,)
# File1 embedding at row 734: Shape (768,)
# File1 embedding at row 735: Shape (768,)
# File1 embedding at row 736: Shape (768,)
# File1 embedding at row 737: Shape (768,)
# File1 embedding at row 738: Shape (768,)
# File1 embedding at row 739: Shape (768,)
# File1 embedding at row 740: Shape (768,)
# File1 embedding at row 741: Shape (768,)
# File1 embedding at row 742: Shape (768,)
# File1 embedding at row 743: Shape (768,)
# File1 embedding at row 744: Shape (768,)
# File1 embedding at row 745: Shape (768,)
# File1 embedding at row 746: Shape (768,)
# File1 embedding at row 747: Shape (768,)
# File1 embedding at row 748: Shape (768,)
# File1 embedding at row 749: Shape (768,)
# File1 embedding at row 750: Shape (768,)
# File1 embedding at row 751: Shape (768,)
# File1 embedding at row 752: Shape (768,)
# File1 embedding at row 753: Shape (768,)
# File1 embedding at row 754: Shape (768,)
# File1 embedding at row 755: Shape (768,)
# File1 embedding at row 756: Shape (768,)
# File1 embedding at row 757: Shape (768,)
# File1 embedding at row 758: Shape (768,)
# File1 embedding at row 759: Shape (768,)
# File1 embedding at row 760: Shape (768,)
# File1 embedding at row 761: Shape (768,)
# File1 embedding at row 762: Shape (768,)
# File1 embedding at row 763: Shape (768,)
# File1 embedding at row 764: Shape (768,)
# File1 embedding at row 765: Shape (768,)
# File1 embedding at row 766: Shape (768,)
# File1 embedding at row 767: Shape (768,)
# File1 embedding at row 768: Shape (768,)
# File1 embedding at row 769: Shape (768,)
# File1 embedding at row 770: Shape (768,)
# File1 embedding at row 771: Shape (768,)
# File1 embedding at row 772: Shape (768,)
# File1 embedding at row 773: Shape (768,)
# File1 embedding at row 774: Shape (768,)
# File1 embedding at row 775: Shape (768,)
# File1 embedding at row 776: Shape (768,)
# File1 embedding at row 777: Shape (768,)
# File1 embedding at row 778: Shape (768,)
# File1 embedding at row 779: Shape (768,)
# File1 embedding at row 780: Shape (768,)
# File1 embedding at row 781: Shape (768,)
# File1 embedding at row 782: Shape (768,)
# File1 embedding at row 783: Shape (768,)
# File1 embedding at row 784: Shape (768,)
# File1 embedding at row 785: Shape (768,)
# File1 embedding at row 786: Shape (768,)
# File1 embedding at row 787: Shape (768,)
# File1 embedding at row 788: Shape (768,)
# File1 embedding at row 789: Shape (768,)
# File1 embedding at row 790: Shape (768,)
# File1 embedding at row 791: Shape (768,)
# File1 embedding at row 792: Shape (768,)
# File1 embedding at row 793: Shape (768,)
# File1 embedding at row 794: Shape (768,)
# File1 embedding at row 795: Shape (768,)
# File1 embedding at row 796: Shape (768,)
# File1 embedding at row 797: Shape (768,)
# File1 embedding at row 798: Shape (768,)
# File1 embedding at row 799: Shape (768,)
# File1 embedding at row 800: Shape (768,)
# File1 embedding at row 801: Shape (768,)
# File1 embedding at row 802: Shape (768,)
# File1 embedding at row 803: Shape (768,)
# File1 embedding at row 804: Shape (768,)
# File1 embedding at row 805: Shape (768,)
# File1 embedding at row 806: Shape (768,)
# File1 embedding at row 807: Shape (768,)
# File1 embedding at row 808: Shape (768,)
# File1 embedding at row 809: Shape (768,)
# File1 embedding at row 810: Shape (768,)
# File1 embedding at row 811: Shape (768,)
# File1 embedding at row 812: Shape (768,)
# File1 embedding at row 813: Shape (768,)
# File1 embedding at row 814: Shape (768,)
# File1 embedding at row 815: Shape (768,)
# File1 embedding at row 816: Shape (768,)
# File1 embedding at row 817: Shape (768,)
# File1 embedding at row 818: Shape (768,)
# File1 embedding at row 819: Shape (768,)
# File1 embedding at row 820: Shape (768,)
# File1 embedding at row 821: Shape (768,)
# File1 embedding at row 822: Shape (768,)
# File1 embedding at row 823: Shape (768,)
# File1 embedding at row 824: Shape (768,)
# File1 embedding at row 825: Shape (768,)
# File1 embedding at row 826: Shape (768,)
# File1 embedding at row 827: Shape (768,)
# File1 embedding at row 828: Shape (768,)
# File1 embedding at row 829: Shape (768,)
# File1 embedding at row 830: Shape (768,)
# File1 embedding at row 831: Shape (768,)
# File1 embedding at row 832: Shape (768,)
# File1 embedding at row 833: Shape (768,)
# File1 embedding at row 834: Shape (768,)
# File1 embedding at row 835: Shape (768,)
# File1 embedding at row 836: Shape (768,)
# File1 embedding at row 837: Shape (768,)
# File1 embedding at row 838: Shape (768,)
# File1 embedding at row 839: Shape (768,)
# File1 embedding at row 840: Shape (768,)
# File1 embedding at row 841: Shape (768,)
# File1 embedding at row 842: Shape (768,)
# File1 embedding at row 843: Shape (768,)
# File1 embedding at row 844: Shape (768,)
# File1 embedding at row 845: Shape (768,)
# File1 embedding at row 846: Shape (768,)
# File1 embedding at row 847: Shape (768,)
# File1 embedding at row 848: Shape (768,)
# File1 embedding at row 849: Shape (768,)
# File1 embedding at row 850: Shape (768,)
# File1 embedding at row 851: Shape (768,)
# File1 embedding at row 852: Shape (768,)
# File1 embedding at row 853: Shape (768,)
# File1 embedding at row 854: Shape (768,)
# File1 embedding at row 855: Shape (768,)
# File1 embedding at row 856: Shape (768,)
# File1 embedding at row 857: Shape (768,)
# File1 embedding at row 858: Shape (768,)
# File1 embedding at row 859: Shape (768,)
# File1 embedding at row 860: Shape (768,)
# File1 embedding at row 861: Shape (768,)
# File1 embedding at row 862: Shape (768,)
# File1 embedding at row 863: Shape (768,)
# File1 embedding at row 864: Shape (768,)
# File1 embedding at row 865: Shape (768,)
# File1 embedding at row 866: Shape (768,)
# File1 embedding at row 867: Shape (768,)
# File1 embedding at row 868: Shape (768,)
# File1 embedding at row 869: Shape (768,)
# File1 embedding at row 870: Shape (768,)
# File1 embedding at row 871: Shape (768,)
# File1 embedding at row 872: Shape (768,)
# File1 embedding at row 873: Shape (768,)
# File1 embedding at row 874: Shape (768,)
# File1 embedding at row 875: Shape (768,)
# File1 embedding at row 876: Shape (768,)
# File1 embedding at row 877: Shape (768,)
# File1 embedding at row 878: Shape (768,)
# File1 embedding at row 879: Shape (768,)
# File1 embedding at row 880: Shape (768,)
# File1 embedding at row 881: Shape (768,)
# File1 embedding at row 882: Shape (768,)
# File1 embedding at row 883: Shape (768,)
# File1 embedding at row 884: Shape (768,)
# File1 embedding at row 885: Shape (768,)
# File1 embedding at row 886: Shape (768,)
# File1 embedding at row 887: Shape (768,)
# File1 embedding at row 888: Shape (768,)
# File1 embedding at row 889: Shape (768,)
# File1 embedding at row 890: Shape (768,)
# File1 embedding at row 891: Shape (768,)
# File1 embedding at row 892: Shape (768,)
# File1 embedding at row 893: Shape (768,)
# File1 embedding at row 894: Shape (768,)
# File1 embedding at row 895: Shape (768,)
# File1 embedding at row 896: Shape (768,)
# File1 embedding at row 897: Shape (768,)
# File1 embedding at row 898: Shape (768,)
# File1 embedding at row 899: Shape (768,)
# File1 embedding at row 900: Shape (768,)
# File1 embedding at row 901: Shape (768,)
# File1 embedding at row 902: Shape (768,)
# File1 embedding at row 903: Shape (768,)
# File1 embedding at row 904: Shape (768,)
# File1 embedding at row 905: Shape (768,)
# File1 embedding at row 906: Shape (768,)
# File1 embedding at row 907: Shape (768,)
# File1 embedding at row 908: Shape (768,)
# File1 embedding at row 909: Shape (768,)
# File1 embedding at row 910: Shape (768,)
# File1 embedding at row 911: Shape (768,)
# File1 embedding at row 912: Shape (768,)
# File1 embedding at row 913: Shape (768,)
# File1 embedding at row 914: Shape (768,)
# File1 embedding at row 915: Shape (768,)
# File1 embedding at row 916: Shape (768,)
# File1 embedding at row 917: Shape (768,)
# File1 embedding at row 918: Shape (768,)
# File1 embedding at row 919: Shape (768,)
# File1 embedding at row 920: Shape (768,)
# File1 embedding at row 921: Shape (768,)
# File1 embedding at row 922: Shape (768,)
# File1 embedding at row 923: Shape (768,)
# File1 embedding at row 924: Shape (768,)
# File1 embedding at row 925: Shape (768,)
# File1 embedding at row 926: Shape (768,)
# File1 embedding at row 927: Shape (768,)
# File1 embedding at row 928: Shape (768,)
# File1 embedding at row 929: Shape (768,)
# File1 embedding at row 930: Shape (768,)
# File1 embedding at row 931: Shape (768,)
# File1 embedding at row 932: Shape (768,)
# File1 embedding at row 933: Shape (768,)
# File1 embedding at row 934: Shape (768,)
# File1 embedding at row 935: Shape (768,)
# File1 embedding at row 936: Shape (768,)
# File1 embedding at row 937: Shape (768,)
# File1 embedding at row 938: Shape (768,)
# File1 embedding at row 939: Shape (768,)
# File1 embedding at row 940: Shape (768,)
# File1 embedding at row 941: Shape (768,)
# File1 embedding at row 942: Shape (768,)
# File1 embedding at row 943: Shape (768,)
# File1 embedding at row 944: Shape (768,)
# File1 embedding at row 945: Shape (768,)
# File1 embedding at row 946: Shape (768,)
# File1 embedding at row 947: Shape (768,)
# File1 embedding at row 948: Shape (768,)
# File1 embedding at row 949: Shape (768,)
# File1 embedding at row 950: Shape (768,)
# File1 embedding at row 951: Shape (768,)
# File1 embedding at row 952: Shape (768,)
# File1 embedding at row 953: Shape (768,)
# File1 embedding at row 954: Shape (768,)
# File1 embedding at row 955: Shape (768,)
# File1 embedding at row 956: Shape (768,)
# File1 embedding at row 957: Shape (768,)
# File1 embedding at row 958: Shape (768,)
# File1 embedding at row 959: Shape (768,)
# File1 embedding at row 960: Shape (768,)
# File1 embedding at row 961: Shape (768,)
# File1 embedding at row 962: Shape (768,)
# File1 embedding at row 963: Shape (768,)
# File1 embedding at row 964: Shape (768,)
# File1 embedding at row 965: Shape (768,)
# File1 embedding at row 966: Shape (768,)
# File1 embedding at row 967: Shape (768,)
# File1 embedding at row 968: Shape (768,)
# File1 embedding at row 969: Shape (768,)
# File1 embedding at row 970: Shape (768,)
# File1 embedding at row 971: Shape (768,)
# File1 embedding at row 972: Shape (768,)
# File1 embedding at row 973: Shape (768,)
# File1 embedding at row 974: Shape (768,)
# File1 embedding at row 975: Shape (768,)
# File1 embedding at row 976: Shape (768,)
# File1 embedding at row 977: Shape (768,)
# File1 embedding at row 978: Shape (768,)
# File1 embedding at row 979: Shape (768,)
# File1 embedding at row 980: Shape (768,)
# File1 embedding at row 981: Shape (768,)
# File1 embedding at row 982: Shape (768,)
# File1 embedding at row 983: Shape (768,)
# File1 embedding at row 984: Shape (768,)
# File1 embedding at row 985: Shape (768,)
# File1 embedding at row 986: Shape (768,)
# File1 embedding at row 987: Shape (768,)
# File1 embedding at row 988: Shape (768,)
# File1 embedding at row 989: Shape (768,)
# File1 embedding at row 990: Shape (768,)
# File1 embedding at row 991: Shape (768,)
# File1 embedding at row 992: Shape (768,)
# File1 embedding at row 993: Shape (768,)
# File1 embedding at row 994: Shape (768,)
# File1 embedding at row 995: Shape (768,)
# File1 embedding at row 996: Shape (768,)
# File1 embedding at row 997: Shape (768,)
# File1 embedding at row 998: Shape (768,)
# File1 embedding at row 999: Shape (768,)
# File1 embedding at row 1000: Shape (768,)
# File1 embedding at row 1001: Shape (768,)
# File1 embedding at row 1002: Shape (768,)
# File1 embedding at row 1003: Shape (768,)
# File1 embedding at row 1004: Shape (768,)
# File1 embedding at row 1005: Shape (768,)
# File1 embedding at row 1006: Shape (768,)
# File1 embedding at row 1007: Shape (768,)
# File1 embedding at row 1008: Shape (768,)
# File1 embedding at row 1009: Shape (768,)
# File1 embedding at row 1010: Shape (768,)
# File1 embedding at row 1011: Shape (768,)
# File1 embedding at row 1012: Shape (768,)
# File1 embedding at row 1013: Shape (768,)
# File1 embedding at row 1014: Shape (768,)
# File1 embedding at row 1015: Shape (768,)
# File1 embedding at row 1016: Shape (768,)
# File1 embedding at row 1017: Shape (768,)
# File1 embedding at row 1018: Shape (768,)
# File1 embedding at row 1019: Shape (768,)
# File1 embedding at row 1020: Shape (768,)
# File1 embedding at row 1021: Shape (768,)
# File1 embedding at row 1022: Shape (768,)
# File1 embedding at row 1023: Shape (768,)
# File1 embedding at row 1024: Shape (768,)
# File1 embedding at row 1025: Shape (768,)
# File1 embedding at row 1026: Shape (768,)
# File1 embedding at row 1027: Shape (768,)
# File1 embedding at row 1028: Shape (768,)
# File1 embedding at row 1029: Shape (768,)
# File1 embedding at row 1030: Shape (768,)
# File1 embedding at row 1031: Shape (768,)
# File1 embedding at row 1032: Shape (768,)
# File1 embedding at row 1033: Shape (768,)
# File1 embedding at row 1034: Shape (768,)
# File1 embedding at row 1035: Shape (768,)
# File1 embedding at row 1036: Shape (768,)
# File1 embedding at row 1037: Shape (768,)
# File1 embedding at row 1038: Shape (768,)
# File1 embedding at row 1039: Shape (768,)
# File1 embedding at row 1040: Shape (768,)
# File1 embedding at row 1041: Shape (768,)
# File1 embedding at row 1042: Shape (768,)
# File1 embedding at row 1043: Shape (768,)
# File1 embedding at row 1044: Shape (768,)
# File1 embedding at row 1045: Shape (768,)
# File1 embedding at row 1046: Shape (768,)
# File1 embedding at row 1047: Shape (768,)
# File1 embedding at row 1048: Shape (768,)
# File1 embedding at row 1049: Shape (768,)
# File1 embedding at row 1050: Shape (768,)
# File1 embedding at row 1051: Shape (768,)
# File1 embedding at row 1052: Shape (768,)
# File1 embedding at row 1053: Shape (768,)
# File1 embedding at row 1054: Shape (768,)
# File1 embedding at row 1055: Shape (768,)
# File1 embedding at row 1056: Shape (768,)
# File1 embedding at row 1057: Shape (768,)
# File1 embedding at row 1058: Shape (768,)
# File1 embedding at row 1059: Shape (768,)
# File1 embedding at row 1060: Shape (768,)
# File1 embedding at row 1061: Shape (768,)
# File1 embedding at row 1062: Shape (768,)
# File1 embedding at row 1063: Shape (768,)
# File1 embedding at row 1064: Shape (768,)
# File1 embedding at row 1065: Shape (768,)
# File1 embedding at row 1066: Shape (768,)
# File1 embedding at row 1067: Shape (768,)
# File1 embedding at row 1068: Shape (768,)
# File1 embedding at row 1069: Shape (768,)
# File1 embedding at row 1070: Shape (768,)
# File1 embedding at row 1071: Shape (768,)
# File1 embedding at row 1072: Shape (768,)
# File1 embedding at row 1073: Shape (768,)
# File1 embedding at row 1074: Shape (768,)
# File1 embedding at row 1075: Shape (768,)
# File1 embedding at row 1076: Shape (768,)
# File1 embedding at row 1077: Shape (768,)
# File1 embedding at row 1078: Shape (768,)
# File1 embedding at row 1079: Shape (768,)
# File1 embedding at row 1080: Shape (768,)
# File1 embedding at row 1081: Shape (768,)
# File1 embedding at row 1082: Shape (768,)
# File1 embedding at row 1083: Shape (768,)
# File1 embedding at row 1084: Shape (768,)
# File1 embedding at row 1085: Shape (768,)
# File1 embedding at row 1086: Shape (768,)
# File1 embedding at row 1087: Shape (768,)
# File1 embedding at row 1088: Shape (768,)
# File1 embedding at row 1089: Shape (768,)
# File1 embedding at row 1090: Shape (768,)
# File1 embedding at row 1091: Shape (768,)
# File1 embedding at row 1092: Shape (768,)
# File1 embedding at row 1093: Shape (768,)
# File1 embedding at row 1094: Shape (768,)
# File1 embedding at row 1095: Shape (768,)
# File1 embedding at row 1096: Shape (768,)
# File1 embedding at row 1097: Shape (768,)
# File1 embedding at row 1098: Shape (768,)
# File1 embedding at row 1099: Shape (768,)
# File1 embedding at row 1100: Shape (768,)
# File1 embedding at row 1101: Shape (768,)
# File1 embedding at row 1102: Shape (768,)
# File1 embedding at row 1103: Shape (768,)
# File1 embedding at row 1104: Shape (768,)
# File1 embedding at row 1105: Shape (768,)
# File1 embedding at row 1106: Shape (768,)
# File1 embedding at row 1107: Shape (768,)
# File1 embedding at row 1108: Shape (768,)
# File1 embedding at row 1109: Shape (768,)
# File1 embedding at row 1110: Shape (768,)
# File1 embedding at row 1111: Shape (768,)
# File1 embedding at row 1112: Shape (768,)
# File1 embedding at row 1113: Shape (768,)
# File1 embedding at row 1114: Shape (768,)
# File1 embedding at row 1115: Shape (768,)
# File1 embedding at row 1116: Shape (768,)
# File1 embedding at row 1117: Shape (768,)
# File1 embedding at row 1118: Shape (768,)
# File1 embedding at row 1119: Shape (768,)
# File1 embedding at row 1120: Shape (768,)
# File1 embedding at row 1121: Shape (768,)
# File1 embedding at row 1122: Shape (768,)
# File1 embedding at row 1123: Shape (768,)
# File1 embedding at row 1124: Shape (768,)
# File1 embedding at row 1125: Shape (768,)
# File1 embedding at row 1126: Shape (768,)
# File1 embedding at row 1127: Shape (768,)
# File1 embedding at row 1128: Shape (768,)
# File1 embedding at row 1129: Shape (768,)
# File1 embedding at row 1130: Shape (768,)
# File1 embedding at row 1131: Shape (768,)
# File1 embedding at row 1132: Shape (768,)
# File1 embedding at row 1133: Shape (768,)
# File1 embedding at row 1134: Shape (768,)
# File1 embedding at row 1135: Shape (768,)
# File1 embedding at row 1136: Shape (768,)
# File1 embedding at row 1137: Shape (768,)
# File1 embedding at row 1138: Shape (768,)
# File1 embedding at row 1139: Shape (768,)
# File1 embedding at row 1140: Shape (768,)
# File1 embedding at row 1141: Shape (768,)
# File1 embedding at row 1142: Shape (768,)
# File1 embedding at row 1143: Shape (768,)
# File1 embedding at row 1144: Shape (768,)
# File1 embedding at row 1145: Shape (768,)
# File1 embedding at row 1146: Shape (768,)
# File1 embedding at row 1147: Shape (768,)
# File1 embedding at row 1148: Shape (768,)
# File1 embedding at row 1149: Shape (768,)
# File1 embedding at row 1150: Shape (768,)
# File1 embedding at row 1151: Shape (768,)
# File1 embedding at row 1152: Shape (768,)
# File1 embedding at row 1153: Shape (768,)
# File1 embedding at row 1154: Shape (768,)
# File1 embedding at row 1155: Shape (768,)
# File1 embedding at row 1156: Shape (768,)
# File1 embedding at row 1157: Shape (768,)
# File1 embedding at row 1158: Shape (768,)
# File1 embedding at row 1159: Shape (768,)
# File1 embedding at row 1160: Shape (768,)
# File1 embedding at row 1161: Shape (768,)
# File1 embedding at row 1162: Shape (768,)
# File1 embedding at row 1163: Shape (768,)
# File1 embedding at row 1164: Shape (768,)
# File1 embedding at row 1165: Shape (768,)
# File1 embedding at row 1166: Shape (768,)
# File1 embedding at row 1167: Shape (768,)
# File1 embedding at row 1168: Shape (768,)
# ...
# File2 embedding at row 577: Shape (768,)
# File2 embedding at row 578: Shape (768,)
# File2 embedding at row 579: Shape (768,)
# File2 embedding at row 580: Shape (768,)
# File2 embedding at row 581: Shape (768,)
# File2 embedding at row 582: Shape (768,)
# File2 embedding at row 583: Shape (768,)
# File2 embedding at row 584: Shape (768,)
# File2 embedding at row 585: Shape (768,)
# File2 embedding at row 586: Shape (768,)
# File2 embedding at row 587: Shape (768,)
# File2 embedding at row 588: Shape (768,)
# File2 embedding at row 589: Shape (768,)
# File2 embedding at row 590: Shape (768,)
# File2 embedding at row 591: Shape (768,)
# File2 embedding at row 592: Shape (768,)
# File2 embedding at row 593: Shape (768,)
# File2 embedding at row 594: Shape (768,)
# File2 embedding at row 595: Shape (768,)
# File2 embedding at row 596: Shape (768,)
# File2 embedding at row 597: Shape (768,)
# File2 embedding at row 598: Shape (768,)
# File2 embedding at row 599: Shape (768,)
# File2 embedding at row 600: Shape (768,)
# File2 embedding at row 601: Shape (768,)
# File2 embedding at row 602: Shape (768,)
# File2 embedding at row 603: Shape (768,)
# File2 embedding at row 604: Shape (768,)
# File2 embedding at row 605: Shape (768,)
# File2 embedding at row 606: Shape (768,)
# File2 embedding at row 607: Shape (768,)
# File2 embedding at row 608: Shape (768,)
# File2 embedding at row 609: Shape (768,)
# File2 embedding at row 610: Shape (768,)
# File2 embedding at row 611: Shape (768,)
# File2 embedding at row 612: Shape (768,)
# File2 embedding at row 613: Shape (768,)
# File2 embedding at row 614: Shape (768,)
# File2 embedding at row 615: Shape (768,)
# File2 embedding at row 616: Shape (768,)
# File2 embedding at row 617: Shape (768,)
# File2 embedding at row 618: Shape (768,)
# File2 embedding at row 619: Shape (768,)
# File2 embedding at row 620: Shape (768,)
# File2 embedding at row 621: Shape (768,)
# File2 embedding at row 622: Shape (768,)
# File2 embedding at row 623: Shape (768,)
# File2 embedding at row 624: Shape (768,)
# File2 embedding at row 625: Shape (768,)
# File2 embedding at row 626: Shape (768,)
# File2 embedding at row 627: Shape (768,)
# File2 embedding at row 628: Shape (768,)
# File2 embedding at row 629: Shape (768,)
# File2 embedding at row 630: Shape (768,)
# File2 embedding at row 631: Shape (768,)
# File2 embedding at row 632: Shape (768,)
# File2 embedding at row 633: Shape (768,)
# File2 embedding at row 634: Shape (768,)
# File2 embedding at row 635: Shape (768,)
# File2 embedding at row 636: Shape (768,)
# File2 embedding at row 637: Shape (768,)
# File2 embedding at row 638: Shape (768,)
# File2 embedding at row 639: Shape (768,)
# File2 embedding at row 640: Shape (768,)
# File2 embedding at row 641: Shape (768,)
# File2 embedding at row 642: Shape (768,)
# File2 embedding at row 643: Shape (768,)
# File2 embedding at row 644: Shape (768,)
# File2 embedding at row 645: Shape (768,)
# File2 embedding at row 646: Shape (768,)
# File2 embedding at row 647: Shape (768,)
# File2 embedding at row 648: Shape (768,)
# File2 embedding at row 649: Shape (768,)
# File2 embedding at row 650: Shape (768,)
# File2 embedding at row 651: Shape (768,)
# File2 embedding at row 652: Shape (768,)
# File2 embedding at row 653: Shape (768,)
# File2 embedding at row 654: Shape (768,)
# File2 embedding at row 655: Shape (768,)
# File2 embedding at row 656: Shape (768,)
# File2 embedding at row 657: Shape (768,)
# File2 embedding at row 658: Shape (768,)
# File2 embedding at row 659: Shape (768,)
# File2 embedding at row 660: Shape (768,)
# File2 embedding at row 661: Shape (768,)
# File2 embedding at row 662: Shape (768,)
# File2 embedding at row 663: Shape (768,)
# File2 embedding at row 664: Shape (768,)
# File2 embedding at row 665: Shape (768,)
# File2 embedding at row 666: Shape (768,)
# File2 embedding at row 667: Shape (768,)
# File2 embedding at row 668: Shape (768,)
# File2 embedding at row 669: Shape (768,)
# File2 embedding at row 670: Shape (768,)
# File2 embedding at row 671: Shape (768,)
# File2 embedding at row 672: Shape (768,)
# File2 embedding at row 673: Shape (768,)
# File2 embedding at row 674: Shape (768,)
# File2 embedding at row 675: Shape (768,)
# File2 embedding at row 676: Shape (768,)
# File2 embedding at row 677: Shape (768,)
# File2 embedding at row 678: Shape (768,)
# File2 embedding at row 679: Shape (768,)
# File2 embedding at row 680: Shape (768,)
# File2 embedding at row 681: Shape (768,)
# File2 embedding at row 682: Shape (768,)
# File2 embedding at row 683: Shape (768,)
# File2 embedding at row 684: Shape (768,)
# File2 embedding at row 685: Shape (768,)
# File2 embedding at row 686: Shape (768,)
# File2 embedding at row 687: Shape (768,)
# File2 embedding at row 688: Shape (768,)
# File2 embedding at row 689: Shape (768,)
# File2 embedding at row 690: Shape (768,)
# File2 embedding at row 691: Shape (768,)
# File2 embedding at row 692: Shape (768,)
# File2 embedding at row 693: Shape (768,)
# File2 embedding at row 694: Shape (768,)
# File2 embedding at row 695: Shape (768,)
# File2 embedding at row 696: Shape (768,)
# File2 embedding at row 697: Shape (768,)
# File2 embedding at row 698: Shape (768,)
# File2 embedding at row 699: Shape (768,)
# File2 embedding at row 700: Shape (768,)
# File2 embedding at row 701: Shape (768,)
# File2 embedding at row 702: Shape (768,)
# File2 embedding at row 703: Shape (768,)
# File2 embedding at row 704: Shape (768,)
# File2 embedding at row 705: Shape (768,)
# File2 embedding at row 706: Shape (768,)
# File2 embedding at row 707: Shape (768,)
# File2 embedding at row 708: Shape (768,)
# File2 embedding at row 709: Shape (768,)
# File2 embedding at row 710: Shape (768,)
# File2 embedding at row 711: Shape (768,)
# File2 embedding at row 712: Shape (768,)
# File2 embedding at row 713: Shape (768,)
# File2 embedding at row 714: Shape (768,)
# File2 embedding at row 715: Shape (768,)
# File2 embedding at row 716: Shape (768,)
# File2 embedding at row 717: Shape (768,)
# File2 embedding at row 718: Shape (768,)
# File2 embedding at row 719: Shape (768,)
# File2 embedding at row 720: Shape (768,)
# File2 embedding at row 721: Shape (768,)
# File2 embedding at row 722: Shape (768,)
# File2 embedding at row 723: Shape (768,)
# File2 embedding at row 724: Shape (768,)
# File2 embedding at row 725: Shape (768,)
# File2 embedding at row 726: Shape (768,)
# File2 embedding at row 727: Shape (768,)
# File2 embedding at row 728: Shape (768,)
# File2 embedding at row 729: Shape (768,)
# File2 embedding at row 730: Shape (768,)
# File2 embedding at row 731: Shape (768,)
# File2 embedding at row 732: Shape (768,)
# File2 embedding at row 733: Shape (768,)
# File2 embedding at row 734: Shape (768,)
# File2 embedding at row 735: Shape (768,)
# File2 embedding at row 736: Shape (768,)
# File2 embedding at row 737: Shape (768,)
# File2 embedding at row 738: Shape (768,)
# File2 embedding at row 739: Shape (768,)
# File2 embedding at row 740: Shape (768,)
# File2 embedding at row 741: Shape (768,)
# File2 embedding at row 742: Shape (768,)
# File2 embedding at row 743: Shape (768,)
# File2 embedding at row 744: Shape (768,)
# File2 embedding at row 745: Shape (768,)
# File2 embedding at row 746: Shape (768,)
# File2 embedding at row 747: Shape (768,)
# File2 embedding at row 748: Shape (768,)
# File2 embedding at row 749: Shape (768,)
# File2 embedding at row 750: Shape (768,)
# File2 embedding at row 751: Shape (768,)
# File2 embedding at row 752: Shape (768,)
# File2 embedding at row 753: Shape (768,)
# File2 embedding at row 754: Shape (768,)
# File2 embedding at row 755: Shape (768,)
# File2 embedding at row 756: Shape (768,)
# File2 embedding at row 757: Shape (768,)
# File2 embedding at row 758: Shape (768,)
# File2 embedding at row 759: Shape (768,)
# File2 embedding at row 760: Shape (768,)
# File2 embedding at row 761: Shape (768,)
# File2 embedding at row 762: Shape (768,)
# File2 embedding at row 763: Shape (768,)
# File2 embedding at row 764: Shape (768,)
# File2 embedding at row 765: Shape (768,)
# File2 embedding at row 766: Shape (768,)
# File2 embedding at row 767: Shape (768,)
# File2 embedding at row 768: Shape (768,)
# File2 embedding at row 769: Shape (768,)
# File2 embedding at row 770: Shape (768,)
# File2 embedding at row 771: Shape (768,)
# File2 embedding at row 772: Shape (768,)
# File2 embedding at row 773: Shape (768,)
# File2 embedding at row 774: Shape (768,)
# File2 embedding at row 775: Shape (768,)
# File2 embedding at row 776: Shape (768,)
# File2 embedding at row 777: Shape (768,)
# File2 embedding at row 778: Shape (768,)
# File2 embedding at row 779: Shape (768,)
# File2 embedding at row 780: Shape (768,)
# File2 embedding at row 781: Shape (768,)
# File2 embedding at row 782: Shape (768,)
# File2 embedding at row 783: Shape (768,)
# File2 embedding at row 784: Shape (768,)
# File2 embedding at row 785: Shape (768,)
# File2 embedding at row 786: Shape (768,)
# File2 embedding at row 787: Shape (768,)
# File2 embedding at row 788: Shape (768,)
# File2 embedding at row 789: Shape (768,)
# File2 embedding at row 790: Shape (768,)
# File2 embedding at row 791: Shape (768,)
# File2 embedding at row 792: Shape (768,)
# File2 embedding at row 793: Shape (768,)
# File2 embedding at row 794: Shape (768,)
# File2 embedding at row 795: Shape (768,)
# File2 embedding at row 796: Shape (768,)
# File2 embedding at row 797: Shape (768,)
# File2 embedding at row 798: Shape (768,)
# File2 embedding at row 799: Shape (768,)
# File2 embedding at row 800: Shape (768,)
# File2 embedding at row 801: Shape (768,)
# File2 embedding at row 802: Shape (768,)
# File2 embedding at row 803: Shape (768,)
# File2 embedding at row 804: Shape (768,)
# File2 embedding at row 805: Shape (768,)
# File2 embedding at row 806: Shape (768,)
# File2 embedding at row 807: Shape (768,)
# File2 embedding at row 808: Shape (768,)
# File2 embedding at row 809: Shape (768,)
# File2 embedding at row 810: Shape (768,)
# File2 embedding at row 811: Shape (768,)
# File2 embedding at row 812: Shape (768,)
# File2 embedding at row 813: Shape (768,)
# File2 embedding at row 814: Shape (768,)
# File2 embedding at row 815: Shape (768,)
# File2 embedding at row 816: Shape (768,)
# File2 embedding at row 817: Shape (768,)
# File2 embedding at row 818: Shape (768,)
# File2 embedding at row 819: Shape (768,)
# File2 embedding at row 820: Shape (768,)
# File2 embedding at row 821: Shape (768,)
# File2 embedding at row 822: Shape (768,)
# File2 embedding at row 823: Shape (768,)
# File2 embedding at row 824: Shape (768,)
# File2 embedding at row 825: Shape (768,)
# File2 embedding at row 826: Shape (768,)
# File2 embedding at row 827: Shape (768,)
# File2 embedding at row 828: Shape (768,)
# File2 embedding at row 829: Shape (768,)
# File2 embedding at row 830: Shape (768,)
# File2 embedding at row 831: Shape (768,)
# File2 embedding at row 832: Shape (768,)
# File2 embedding at row 833: Shape (768,)
# File2 embedding at row 834: Shape (768,)
# File2 embedding at row 835: Shape (768,)
# File2 embedding at row 836: Shape (768,)
# File2 embedding at row 837: Shape (768,)
# File2 embedding at row 838: Shape (768,)
# File2 embedding at row 839: Shape (768,)
# File2 embedding at row 840: Shape (768,)
# File2 embedding at row 841: Shape (768,)
# File2 embedding at row 842: Shape (768,)
# File2 embedding at row 843: Shape (768,)
# File2 embedding at row 844: Shape (768,)
# File2 embedding at row 845: Shape (768,)
# File2 embedding at row 846: Shape (768,)
# File2 embedding at row 847: Shape (768,)
# File2 embedding at row 848: Shape (768,)
# File2 embedding at row 849: Shape (768,)
# File2 embedding at row 850: Shape (768,)
# File2 embedding at row 851: Shape (768,)
# File2 embedding at row 852: Shape (768,)
# File2 embedding at row 853: Shape (768,)
# File2 embedding at row 854: Shape (768,)
# File2 embedding at row 855: Shape (768,)
# File2 embedding at row 856: Shape (768,)
# File2 embedding at row 857: Shape (768,)
# File2 embedding at row 858: Shape (768,)
# File2 embedding at row 859: Shape (768,)
# File2 embedding at row 860: Shape (768,)
# File2 embedding at row 861: Shape (768,)
# File2 embedding at row 862: Shape (768,)
# File2 embedding at row 863: Shape (768,)
# File2 embedding at row 864: Shape (768,)
# File2 embedding at row 865: Shape (768,)
# File2 embedding at row 866: Shape (768,)
# File2 embedding at row 867: Shape (768,)
# File2 embedding at row 868: Shape (768,)
# File2 embedding at row 869: Shape (768,)
# File2 embedding at row 870: Shape (768,)
# File2 embedding at row 871: Shape (768,)
# File2 embedding at row 872: Shape (768,)
# File2 embedding at row 873: Shape (768,)
# File2 embedding at row 874: Shape (768,)
# File2 embedding at row 875: Shape (768,)
# File2 embedding at row 876: Shape (768,)
# File2 embedding at row 877: Shape (768,)
# File2 embedding at row 878: Shape (768,)
# File2 embedding at row 879: Shape (768,)
# File2 embedding at row 880: Shape (768,)
# File2 embedding at row 881: Shape (768,)
# File2 embedding at row 882: Shape (768,)
# File2 embedding at row 883: Shape (768,)
# File2 embedding at row 884: Shape (768,)
# File2 embedding at row 885: Shape (768,)
# File2 embedding at row 886: Shape (768,)
# File2 embedding at row 887: Shape (768,)
# File2 embedding at row 888: Shape (768,)
# File2 embedding at row 889: Shape (768,)
# File2 embedding at row 890: Shape (768,)
# File2 embedding at row 891: Shape (768,)
# File2 embedding at row 892: Shape (768,)
# File2 embedding at row 893: Shape (768,)
# File2 embedding at row 894: Shape (768,)
# File2 embedding at row 895: Shape (768,)
# File2 embedding at row 896: Shape (768,)
# File2 embedding at row 897: Shape (768,)
# File2 embedding at row 898: Shape (768,)
# File2 embedding at row 899: Shape (768,)
# File2 embedding at row 900: Shape (768,)
# File2 embedding at row 901: Shape (768,)
# File2 embedding at row 902: Shape (768,)
# File2 embedding at row 903: Shape (768,)
# File2 embedding at row 904: Shape (768,)
# File2 embedding at row 905: Shape (768,)
# File2 embedding at row 906: Shape (768,)
# File2 embedding at row 907: Shape (768,)
# File2 embedding at row 908: Shape (768,)
# File2 embedding at row 909: Shape (768,)
# File2 embedding at row 910: Shape (768,)
# File2 embedding at row 911: Shape (768,)
# File2 embedding at row 912: Shape (768,)
# File2 embedding at row 913: Shape (768,)
# File2 embedding at row 914: Shape (768,)
# File2 embedding at row 915: Shape (768,)
# File2 embedding at row 916: Shape (768,)
# File2 embedding at row 917: Shape (768,)
# File2 embedding at row 918: Shape (768,)
# File2 embedding at row 919: Shape (768,)
# File2 embedding at row 920: Shape (768,)
# File2 embedding at row 921: Shape (768,)
# File2 embedding at row 922: Shape (768,)
# File2 embedding at row 923: Shape (768,)
# File2 embedding at row 924: Shape (768,)
# File2 embedding at row 925: Shape (768,)
# File2 embedding at row 926: Shape (768,)
# File2 embedding at row 927: Shape (768,)
# File2 embedding at row 928: Shape (768,)
# File2 embedding at row 929: Shape (768,)
# File2 embedding at row 930: Shape (768,)
# File2 embedding at row 931: Shape (768,)
# File2 embedding at row 932: Shape (768,)
# File2 embedding at row 933: Shape (768,)
# File2 embedding at row 934: Shape (768,)
# File2 embedding at row 935: Shape (768,)
# File2 embedding at row 936: Shape (768,)
# File2 embedding at row 937: Shape (768,)
# File2 embedding at row 938: Shape (768,)
# File2 embedding at row 939: Shape (768,)
# File2 embedding at row 940: Shape (768,)
# File2 embedding at row 941: Shape (768,)
# File2 embedding at row 942: Shape (768,)
# File2 embedding at row 943: Shape (768,)
# File2 embedding at row 944: Shape (768,)
# File2 embedding at row 945: Shape (768,)
# File2 embedding at row 946: Shape (768,)
# File2 embedding at row 947: Shape (768,)
# File2 embedding at row 948: Shape (768,)
# File2 embedding at row 949: Shape (768,)
# File2 embedding at row 950: Shape (768,)
# File2 embedding at row 951: Shape (768,)
# File2 embedding at row 952: Shape (768,)
# File2 embedding at row 953: Shape (768,)
# File2 embedding at row 954: Shape (768,)
# File2 embedding at row 955: Shape (768,)
# File2 embedding at row 956: Shape (768,)
# File2 embedding at row 957: Shape (768,)
# File2 embedding at row 958: Shape (768,)
# File2 embedding at row 959: Shape (768,)
# File2 embedding at row 960: Shape (768,)
# File2 embedding at row 961: Shape (768,)
# File2 embedding at row 962: Shape (768,)
# File2 embedding at row 963: Shape (768,)
# File2 embedding at row 964: Shape (768,)
# File2 embedding at row 965: Shape (768,)
# File2 embedding at row 966: Shape (768,)

# %% [markdown]
# ### Initialize columns for top 3 matches in file1

# %%
for i in range(1, 4):  # Top 3 matches
    file1[f'ID (Iso) - Match {i}'] = ""
    file1[f'Title (Iso) - Match {i}'] = ""
    file1[f'Similarity Score(Iso) - Match {i}'] = 0.0

# %% [markdown]
# ### Find the top 3 matches for each control in file1

# %%
for idx1, row1 in file1.iterrows():
    similarities = []

    for idx2, row2 in file2.iterrows():
        sim_score = cosine_similarity([row1['embedding']], [row2['embedding']])[0][0]

        # Store each match with its similarity score
        similarities.append((sim_score, row2['ID'], row2['Description']))

    # Sort to get the top 3 matches
    top_matches = sorted(similarities, key=lambda x: x[0], reverse=True)[:3]

# %% [markdown]
# ## # Append the top 3 matches to file1's new columns

# %%
    for i, match in enumerate(top_matches):
        file1.at[idx1, f'ID (File 2) - Match {i + 1}'] = match[1]  # ID
        file1.at[idx1, f'Title (File 2) - Match {i + 1}'] = match[2]  # Title
        file1.at[idx1, f'Similarity Score - Match {i + 1}'] = match[0]  # Similarity score

# %% [markdown]
# ### Drop intermediate columns and save the final output

# %%
file1.drop(columns=['text_combined', 'embedding'], inplace=True)
file1.to_excel('CSF-aeIASv6.xlsx', index=False)

# %%
output = pd.read_excel('CSF-aeIASv6.xlsx')
print("Output:")
display(output.head())
